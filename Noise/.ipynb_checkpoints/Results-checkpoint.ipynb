# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
import matplotlib.pyplot as plt

# %% [markdown]
# ## Attribute Noise Results

# %%
# Load Attribute Noise Cleaned Dataset

an_cleaned = pd.read_csv('attribute_noise_cleaned.csv')
an_cleaned = an_cleaned.drop(['class_name', 'contents'], axis=1)
X = an_cleaned[0:1941]
y = an_cleaned.iloc[:,-1]

# %%
# Create training and test split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=1)

# %%
# Standardize the data set

sc = StandardScaler()
sc.fit(X_train)
X_train_std = sc.transform(X_train)
X_test_std = sc.transform(X_test)

# Fit the SVC model

svc = SVC(kernel='linear', C=10.0, random_state=1)
svc.fit(X_train, y_train)

# Get the predictions

y_pred = svc.predict(X_test)

# Calculate the confusion matrix

conf_matrix = confusion_matrix(y_true=y_test, y_pred=y_pred)

# Print the confusion matrix using Matplotlib

fig, ax = plt.subplots(figsize=(5, 5))
ax.matshow(conf_matrix, cmap=plt.cm.Oranges, alpha=0.3)
for i in range(conf_matrix.shape[0]):
    for j in range(conf_matrix.shape[1]):
        ax.text(x=j, y=i,s=conf_matrix[i, j], va='center', ha='center', size='xx-large')

plt.xlabel('Predictions', fontsize=18)
plt.ylabel('Actuals', fontsize=18)
plt.title('Confusion Matrix', fontsize=18)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 11
#       8 # Fit the SVC model
#      10 svc = SVC(kernel='linear', C=10.0, random_state=1)
# ---> 11 svc.fit(X_train, y_train)
#      13 # Get the predictions
#      15 y_pred = svc.predict(X_test)
#
# File C:\Python311\Lib\site-packages\sklearn\svm\_base.py:182, in BaseLibSVM.fit(self, X, y, sample_weight)
#     172 else:
#     173     X, y = self._validate_data(
#     174         X,
#     175         y,
#    (...)
#     179         accept_large_sparse=False,
#     180     )
# --> 182 y = self._validate_targets(y)
#     184 sample_weight = np.asarray(
#     185     [] if sample_weight is None else sample_weight, dtype=np.float64
#     186 )
#     187 solver_type = LIBSVM_IMPL.index(self._impl)
#
# File C:\Python311\Lib\site-packages\sklearn\svm\_base.py:735, in BaseSVC._validate_targets(self, y)
#     733 def _validate_targets(self, y):
#     734     y_ = column_or_1d(y, warn=True)
# --> 735     check_classification_targets(y)
#     736     cls, y = np.unique(y_, return_inverse=True)
#     737     self.class_weight_ = compute_class_weight(self.class_weight, classes=cls, y=y_)
#
# File C:\Python311\Lib\site-packages\sklearn\utils\multiclass.py:200, in check_classification_targets(y)
#     192 y_type = type_of_target(y, input_name="y")
#     193 if y_type not in [
#     194     "binary",
#     195     "multiclass",
#    (...)
#     198     "multilabel-sequences",
#     199 ]:
# --> 200     raise ValueError("Unknown label type: %r" % y_type)
#
# ValueError: Unknown label type: 'continuous'

# %%
# Precision Score

print('Precision: %.3f' % precision_score(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 3
#       1 # Precision Score
# ----> 3 print('Precision: %.3f' % precision_score(y_test, y_pred))
#
# File C:\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1776, in precision_score(y_true, y_pred, labels, pos_label, average, sample_weight, zero_division)
#    1647 def precision_score(
#    1648     y_true,
#    1649     y_pred,
#    (...)
#    1655     zero_division="warn",
#    1656 ):
#    1657     """Compute the precision.
#    1658
#    1659     The precision is the ratio ``tp / (tp + fp)`` where ``tp`` is the number of
#    (...)
#    1774     array([0.5, 1. , 1. ])
#    1775     """
# -> 1776     p, _, _, _ = precision_recall_fscore_support(
#    1777         y_true,
#    1778         y_pred,
#    1779         labels=labels,
#    1780         pos_label=pos_label,
#    1781         average=average,
#    1782         warn_for=("precision",),
#    1783         sample_weight=sample_weight,
#    1784         zero_division=zero_division,
#    1785     )
#    1786     return p
#
# File C:\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1563, in precision_recall_fscore_support(y_true, y_pred, beta, labels, pos_label, average, warn_for, sample_weight, zero_division)
#    1561 if beta < 0:
#    1562     raise ValueError("beta should be >=0 in the F-beta score")
# -> 1563 labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1565 # Calculate tp_sum, pred_sum, true_sum ###
#    1566 samplewise = average == "samples"
#
# File C:\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1364, in _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1361 if average not in average_options and average != "binary":
#    1362     raise ValueError("average has to be one of " + str(average_options))
# -> 1364 y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#    1365 # Convert to Python primitive type to avoid NumPy type / Python str
#    1366 # comparison. See https://github.com/numpy/numpy/issues/6784
#    1367 present_labels = unique_labels(y_true, y_pred).tolist()
#
# File C:\Python311\Lib\site-packages\sklearn\metrics\_classification.py:93, in _check_targets(y_true, y_pred)
#      90     y_type = {"multiclass"}
#      92 if len(y_type) > 1:
# ---> 93     raise ValueError(
#      94         "Classification metrics can't handle a mix of {0} and {1} targets".format(
#      95             type_true, type_pred
#      96         )
#      97     )
#      99 # We can't have more than one value on y_type => The set is no more needed
#     100 y_type = y_type.pop()
#
# ValueError: Classification metrics can't handle a mix of continuous and multiclass targets

# %%
# Recall Score

print('Recall: %.3f' % recall_score(y_test, y_pred))

# %%
# F1 Score

print('F1 Score: %.3f' % f1_score(y_test, y_pred))

# %%
# Accuracy Score

print('Accuracy: %.3f' % accuracy_score(y_test, y_pred))
